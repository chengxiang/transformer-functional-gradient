# %%
import torch
from matplotlib import pyplot as plt
import sys
import time
import os
import numpy as np
import math


##############################################################################################################
# Trains a linear Transformer with 1,2,3,4 layers
# Plots the test loss of trained Transformer against 1,2,3,4 steps of gradient descent (with and without preconditioning)
##############################################################################################################

#use cuda if available, else use cpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0)
# import the model and some useful functions
from linear_transformer import Transformer_F, attention, in_context_loss, generate_data_inplace, Transformer_C

# set up some print options
np.set_printoptions(precision = 2, suppress = True)
torch.set_printoptions(precision=2)

#begin logging
cur_dir = 'log' 
os.makedirs(cur_dir, exist_ok=True)
#f = open(cur_dir + '/rotation.log', "a", 1)
#sys.stdout = f

# Set up common problem parameters

lr = 0.002
clip_r = lr
alg = 'adam'
mode = 'sphere'

d = 5        # dimension


n_head = 1  # 1-headed attention
B = 30000  # 1000 minibatch size
var = 0.0001  # initializations scale of transformer parameter
shape_k = 0.1  # shape_k: parameter for Gamma distributed covariates
max_iters = 2100  # Number of Iterations to run
print('setting max_iters to 2100 for quick run, need about 40100 for 7 layers')
hist_stride = 1  # stride for saved model paramters in `train.ipynb'
stride = 400

# a convenience function for taking a step and clipping
def clip_and_step(allparam, optimizer, clip_r = None):
    norm_p=None
    grad_all = allparam.grad
    for i in range(0,allparam.shape[0]):
        norm_p = grad_all[i,:,:,:,:].norm().item()
        if norm_p > (clip_r/(8-i+1)**2):
            grad_all[i,:,:,:,:].mul_((clip_r/(8-i+1)**2)/norm_p)
            fraction = (clip_r/(8-i+1)**2)/norm_p
        else:
            fraction = 1.0
    optimizer.step()
    return fraction

#format for saving run data
filename_format = '/run_{}_{}_{}_{}_{}.pth'
n_layers = [3]  # number of layers of transformer

# %%
def run_exp(data_activation, kernel_activation, N, keys):
    print(f"lr: {lr}")
    for key in keys:
        sd = key[0]
        n_layer = key[1]
        filename = cur_dir + filename_format.format(data_activation, kernel_activation, N, sd, n_layer)
        print(key)

        prob_seed = sd
        opt_seed = sd

        hist = []

        #set seed and initialize model
        torch.manual_seed(opt_seed)
        model = Transformer_F(n_layer, 1, d, 0.1, N=N)
        model.to(device)
        #initialize algorithm. Important: set beta = 0.9 for adam, 0.999 is very slow
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, betas=(0.99, 0.99), weight_decay=0)
        residual_betas = (0.9, 0.9)

        # set seed
        # sample random rotation matrix
        # initialize initial training batch
        np.random.seed(prob_seed)
        torch.manual_seed(prob_seed)
        gaus = torch.FloatTensor(d,d).uniform_(-1,1).cuda()
        U = torch.linalg.svd (gaus)[0].cuda()
        #D = torch.diag(torch.FloatTensor([1,1,1/2,1/1.5,1])).cuda()
        D = torch.eye(d).cuda()
        Z = torch.zeros([B,N+1,d+1])
        y = Z[:,-1,-1]
        Z = Z.to(device)
        y = y.to(device)

        reference_lr = lr
        residual_lr = reference_lr

        Z,y = generate_data_inplace(Z,data_activation, U=U, D=D )
        eff_t = 0
        for t in range(max_iters):
            optimizer.param_groups[0]['lr'] = residual_lr
            optimizer.param_groups[0]['betas'] = residual_betas
            if t%4000==0 and t>20000:
                reference_lr = reference_lr * 0.5
            start = time.time()
            # save model parameters
            if t%stride ==0:
                hist.append(model.allparam.clone().detach())

            loss = in_context_loss(model, Z, y, kernel_activation)
            # compute gradient, take step
            loss.backward()
            if t>8000:
                fraction_elapsed_time = clip_and_step(model.allparam, optimizer, clip_r=0.0000001)
            else:
                fraction_elapsed_time = clip_and_step(model.allparam, optimizer, clip_r=0.00000001)
            model.zero_row_col()
            norms = model.allparam.grad.norm().item()
            optimizer.zero_grad()

            if t%10==0:
                Z,y = generate_data_inplace(Z,data_activation, U=U, D=D)

            end=time.time()
            if t%100 ==0 or t<5:
                print('iter {} | Loss: {:.3}  time: {:.2}  gradnorm: {:.2}, fraction:{:.2}, efft:{}'\
                      .format(t,loss.item(), end-start, norms, fraction_elapsed_time, eff_t))
        torch.save({'hist':hist, 'U':U, 'D':D}, filename)
        
def run_comb_exp(data_activation, N, keys):
    print(f"lr: {lr}")
    kernel_activation = 'combact3'
    for key in keys:
        sd = key[0]
        n_layer = key[1]
        filename = cur_dir + filename_format.format(data_activation, kernel_activation, N, sd, n_layer)
        print(key)

        prob_seed = sd
        opt_seed = sd

        hist = []

        #set seed and initialize model
        torch.manual_seed(opt_seed)
        model = Transformer_C(n_layer, 2, d, 0.1, N=N)
        model.to(device)
        #initialize algorithm. Important: set beta = 0.9 for adam, 0.999 is very slow
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, betas=(0.99, 0.99), weight_decay=0)
        residual_betas = (0.9, 0.9)

        # set seed
        # sample random rotation matrix
        # initialize initial training batch
        np.random.seed(prob_seed)
        torch.manual_seed(prob_seed)
        gaus = torch.FloatTensor(d,d).uniform_(-1,1).cuda()
        U = torch.linalg.svd (gaus)[0].cuda()
        #D = torch.diag(torch.FloatTensor([1,1,1/2,1/1.5,1])).cuda()
        D = torch.eye(d).cuda()
        Z = torch.zeros([B,N+1,d+1])
        y = Z[:,-1,-1]
        Z = Z.to(device)
        y = y.to(device)

        reference_lr = lr
        residual_lr = reference_lr

        Z,y = generate_data_inplace(Z,data_activation, U=U, D=D )
        eff_t = 0
        for t in range(max_iters):
            optimizer.param_groups[0]['lr'] = residual_lr
            optimizer.param_groups[0]['betas'] = residual_betas
            if t%4000==0 and t>20000:
                reference_lr = reference_lr * 0.5
            start = time.time()
            # save model parameters
            if t%stride ==0:
                hist.append(model.allparam.clone().detach())

            loss = in_context_loss(model, Z, y, kernel_activation)
            # compute gradient, take step
            loss.backward()
            if t>8000:
                fraction_elapsed_time = clip_and_step(model.allparam, optimizer, clip_r=0.0000001)
            else:
                fraction_elapsed_time = clip_and_step(model.allparam, optimizer, clip_r=0.00000001)
            model.zero_row_col()
            norms = model.allparam.grad.norm().item()
            optimizer.zero_grad()

            if t%10==0:
                Z,y = generate_data_inplace(Z,data_activation, U=U, D=D)

            end=time.time()
            if t%100 ==0 or t<5:
                #print(residual_lr)
                #print(eff_t)
                print('iter {} | Loss: {:.3}  time: {:.2}  gradnorm: {:.2}, fraction:{:.2}, efft:{}'\
                      .format(t,loss.item(), end-start, norms, fraction_elapsed_time, eff_t))
        torch.save({'hist':hist, 'U':U, 'D':D}, filename)

# %%
####################################
# run experiments
####################################
Ns = [8]    # context length
seeds=[0,1,2]
n_layers = [1,3,5,7]
keys = []
for s in seeds:
    for n_layer in n_layers:
        keys.append((s,n_layer,))
        
        
lr = 0.1
for N in Ns:
    run_comb_exp('euclidean',N,keys)
    #run_comb_exp('exp',N,keys)
    #run_comb_exp('comb',N,keys)

    run_exp('euclidean', 'exp', N, keys)
    #run_exp('exp', 'exp', N, keys)
    #run_exp('comb', 'exp', N, keys)
    
    run_exp('euclidean', 'linear', N, keys)
    #run_exp('exp', 'linear', N, keys)
    #run_exp('comb', 'linear', N, keys)
# Out:
# lr: 0.1
# (0, 1)
# iter 0 | Loss: 0.989  time: 0.1  gradnorm: 1.2e-10, fraction:8.9e-09, efft:0
# iter 1 | Loss: 0.996  time: 0.073  gradnorm: 1.2e-10, fraction:1.6e-08, efft:0
# iter 2 | Loss: 0.996  time: 0.03  gradnorm: 1.2e-10, fraction:1.6e-08, efft:0
# iter 3 | Loss: 0.996  time: 0.011  gradnorm: 1.2e-10, fraction:1.6e-08, efft:0
# iter 4 | Loss: 0.996  time: 0.011  gradnorm: 1.2e-10, fraction:1.6e-08, efft:0
# iter 100 | Loss: 0.988  time: 0.013  gradnorm: 1.2e-10, fraction:2.7e-08, efft:0
# iter 200 | Loss: 1.01  time: 0.013  gradnorm: 1.2e-10, fraction:1.3e-08, efft:0
# iter 300 | Loss: 1.0  time: 0.013  gradnorm: 1.2e-10, fraction:2.7e-08, efft:0
# iter 400 | Loss: 0.987  time: 0.014  gradnorm: 1.2e-10, fraction:4.7e-08, efft:0
# iter 500 | Loss: 1.0  time: 0.013  gradnorm: 1.2e-10, fraction:1.6e-08, efft:0
# iter 600 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:2.5e-08, efft:0
# iter 700 | Loss: 0.996  time: 0.013  gradnorm: 1.2e-10, fraction:2.3e-08, efft:0
# iter 800 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 900 | Loss: 0.995  time: 0.014  gradnorm: 1.2e-10, fraction:2.2e-08, efft:0
# iter 1000 | Loss: 1.0  time: 0.013  gradnorm: 1.2e-10, fraction:1.5e-08, efft:0
# iter 1100 | Loss: 0.997  time: 0.013  gradnorm: 1.2e-10, fraction:1.4e-08, efft:0
# iter 1200 | Loss: 1.01  time: 0.014  gradnorm: 1.2e-10, fraction:7.7e-09, efft:0
# iter 1300 | Loss: 0.995  time: 0.014  gradnorm: 1.2e-10, fraction:7.1e-09, efft:0
# iter 1400 | Loss: 0.992  time: 0.013  gradnorm: 1.2e-10, fraction:6e-09, efft:0
# iter 1500 | Loss: 1.0  time: 0.013  gradnorm: 1.2e-10, fraction:5.2e-09, efft:0
# iter 1600 | Loss: 0.983  time: 0.014  gradnorm: 1.2e-10, fraction:4e-09, efft:0
# iter 1700 | Loss: 0.977  time: 0.015  gradnorm: 1.2e-10, fraction:3.2e-09, efft:0
# iter 1800 | Loss: 0.985  time: 0.014  gradnorm: 1.2e-10, fraction:2.7e-09, efft:0
# iter 1900 | Loss: 0.968  time: 0.016  gradnorm: 1.2e-10, fraction:2.2e-09, efft:0
# iter 2000 | Loss: 0.959  time: 0.014  gradnorm: 1.2e-10, fraction:2.1e-09, efft:0
# (0, 3)
# iter 0 | Loss: 0.99  time: 0.038  gradnorm: 2.9e-10, fraction:1.5e-08, efft:0
# iter 1 | Loss: 0.997  time: 0.032  gradnorm: 2.9e-10, fraction:1.9e-08, efft:0
# iter 2 | Loss: 0.997  time: 0.032  gradnorm: 2.9e-10, fraction:1.9e-08, efft:0
# iter 3 | Loss: 0.997  time: 0.033  gradnorm: 2.9e-10, fraction:2e-08, efft:0
# iter 4 | Loss: 0.997  time: 0.032  gradnorm: 2.9e-10, fraction:2e-08, efft:0
# iter 100 | Loss: 0.988  time: 0.038  gradnorm: 2.9e-10, fraction:4.8e-08, efft:0
# iter 200 | Loss: 1.01  time: 0.037  gradnorm: 2.9e-10, fraction:2.8e-08, efft:0
# iter 300 | Loss: 1.0  time: 0.037  gradnorm: 2.9e-10, fraction:2.5e-08, efft:0
# iter 400 | Loss: 0.98  time: 0.041  gradnorm: 2.9e-10, fraction:1.7e-08, efft:0
# iter 500 | Loss: 0.986  time: 0.04  gradnorm: 2.9e-10, fraction:7.1e-09, efft:0
# iter 600 | Loss: 0.97  time: 0.04  gradnorm: 2.9e-10, fraction:5.2e-09, efft:0
# iter 700 | Loss: 0.944  time: 0.041  gradnorm: 2.9e-10, fraction:3.6e-09, efft:0
# iter 800 | Loss: 0.922  time: 0.038  gradnorm: 2.9e-10, fraction:2.8e-09, efft:0
# iter 900 | Loss: 0.884  time: 0.041  gradnorm: 2.9e-10, fraction:2.2e-09, efft:0
# iter 1000 | Loss: 0.852  time: 0.038  gradnorm: 2.9e-10, fraction:1.8e-09, efft:0
# iter 1100 | Loss: 0.803  time: 0.037  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 1200 | Loss: 0.763  time: 0.038  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1300 | Loss: 0.704  time: 0.039  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1400 | Loss: 0.652  time: 0.041  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1500 | Loss: 0.609  time: 0.041  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1600 | Loss: 0.553  time: 0.04  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1700 | Loss: 0.507  time: 0.044  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 1800 | Loss: 0.466  time: 0.043  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 1900 | Loss: 0.425  time: 0.039  gradnorm: 2.9e-10, fraction:1.9e-09, efft:0
# iter 2000 | Loss: 0.393  time: 0.041  gradnorm: 2.9e-10, fraction:2.4e-09, efft:0
# (0, 5)
# iter 0 | Loss: 0.994  time: 0.069  gradnorm: 5.6e-10, fraction:7.4e-09, efft:0
# iter 1 | Loss: 1.0  time: 0.067  gradnorm: 5.6e-10, fraction:9e-09, efft:0
# iter 2 | Loss: 0.999  time: 0.067  gradnorm: 5.6e-10, fraction:9.8e-09, efft:0
# iter 3 | Loss: 0.999  time: 0.063  gradnorm: 5.6e-10, fraction:1.1e-08, efft:0
# iter 4 | Loss: 0.998  time: 0.066  gradnorm: 5.6e-10, fraction:1.2e-08, efft:0
# iter 100 | Loss: 0.986  time: 0.074  gradnorm: 5.6e-10, fraction:3.9e-08, efft:0
# iter 200 | Loss: 0.991  time: 0.069  gradnorm: 5.6e-10, fraction:1.2e-08, efft:0
# iter 300 | Loss: 0.956  time: 0.077  gradnorm: 5.6e-10, fraction:6e-09, efft:0
# iter 400 | Loss: 0.886  time: 0.072  gradnorm: 5.6e-10, fraction:4e-09, efft:0
# iter 500 | Loss: 0.824  time: 0.073  gradnorm: 5.6e-10, fraction:2.9e-09, efft:0
# iter 600 | Loss: 0.734  time: 0.07  gradnorm: 5.6e-10, fraction:2.5e-09, efft:0
# iter 700 | Loss: 0.639  time: 0.072  gradnorm: 5.6e-10, fraction:2.6e-09, efft:0
# iter 800 | Loss: 0.544  time: 0.074  gradnorm: 5.6e-10, fraction:3e-09, efft:0
# iter 900 | Loss: 0.459  time: 0.07  gradnorm: 5.6e-10, fraction:4.3e-09, efft:0
# iter 1000 | Loss: 0.404  time: 0.072  gradnorm: 5.6e-10, fraction:7.2e-09, efft:0
# iter 1100 | Loss: 0.36  time: 0.072  gradnorm: 5.6e-10, fraction:9.1e-09, efft:0
# iter 1200 | Loss: 0.33  time: 0.07  gradnorm: 5.6e-10, fraction:1.5e-08, efft:0
# iter 1300 | Loss: 0.311  time: 0.076  gradnorm: 5.6e-10, fraction:2.2e-08, efft:0
# iter 1400 | Loss: 0.295  time: 0.066  gradnorm: 5.6e-10, fraction:2.9e-08, efft:0
# iter 1500 | Loss: 0.283  time: 0.069  gradnorm: 5.6e-10, fraction:1.8e-08, efft:0
# iter 1600 | Loss: 0.266  time: 0.077  gradnorm: 5.6e-10, fraction:2.6e-08, efft:0
# iter 1700 | Loss: 0.25  time: 0.066  gradnorm: 5.6e-10, fraction:3.3e-08, efft:0
# iter 1800 | Loss: 0.235  time: 0.073  gradnorm: 5.6e-10, fraction:4.7e-08, efft:0
# iter 1900 | Loss: 0.218  time: 0.075  gradnorm: 5.6e-10, fraction:3.4e-08, efft:0
# iter 2000 | Loss: 0.205  time: 0.076  gradnorm: 5.6e-10, fraction:3.5e-08, efft:0
# (0, 7)
# iter 0 | Loss: 0.995  time: 0.1  gradnorm: 1.4e-09, fraction:2.1e-08, efft:0
# iter 1 | Loss: 0.998  time: 0.096  gradnorm: 1.4e-09, fraction:3.3e-08, efft:0
# iter 2 | Loss: 0.997  time: 0.095  gradnorm: 1.4e-09, fraction:4.3e-08, efft:0
# iter 3 | Loss: 0.997  time: 0.096  gradnorm: 1.4e-09, fraction:5.8e-08, efft:0
# iter 4 | Loss: 0.996  time: 0.092  gradnorm: 1.4e-09, fraction:8.2e-08, efft:0
# iter 100 | Loss: 0.968  time: 0.1  gradnorm: 1.4e-09, fraction:3.7e-08, efft:0
# iter 200 | Loss: 0.857  time: 0.097  gradnorm: 1.4e-09, fraction:1e-08, efft:0
# iter 300 | Loss: 0.635  time: 0.097  gradnorm: 1.4e-09, fraction:8.4e-09, efft:0
# iter 400 | Loss: 0.445  time: 0.1  gradnorm: 1.4e-09, fraction:1.3e-08, efft:0
# iter 500 | Loss: 0.357  time: 0.096  gradnorm: 1.4e-09, fraction:3.6e-08, efft:0
# iter 600 | Loss: 0.303  time: 0.1  gradnorm: 1.4e-09, fraction:3.6e-08, efft:0
# iter 700 | Loss: 0.277  time: 0.098  gradnorm: 1.4e-09, fraction:6.1e-08, efft:0
# iter 800 | Loss: 0.249  time: 0.097  gradnorm: 1.4e-09, fraction:7.5e-08, efft:0
# iter 900 | Loss: 0.231  time: 0.093  gradnorm: 1.4e-09, fraction:9.8e-08, efft:0
# iter 1000 | Loss: 0.215  time: 0.096  gradnorm: 1.4e-09, fraction:1.1e-07, efft:0
# iter 1100 | Loss: 0.196  time: 0.094  gradnorm: 1.4e-09, fraction:7.3e-08, efft:0
# iter 1200 | Loss: 0.18  time: 0.097  gradnorm: 1.4e-09, fraction:1.3e-07, efft:0
# iter 1300 | Loss: 0.164  time: 0.094  gradnorm: 1.4e-09, fraction:1.6e-07, efft:0
# iter 1400 | Loss: 0.152  time: 0.1  gradnorm: 1.4e-09, fraction:2.1e-07, efft:0
# iter 1500 | Loss: 0.139  time: 0.1  gradnorm: 1.4e-09, fraction:1.3e-07, efft:0
# iter 1600 | Loss: 0.126  time: 0.1  gradnorm: 1.4e-09, fraction:1.3e-07, efft:0
# iter 1700 | Loss: 0.113  time: 0.099  gradnorm: 1.4e-09, fraction:1.3e-07, efft:0
# iter 1800 | Loss: 0.106  time: 0.1  gradnorm: 1.4e-09, fraction:1.7e-07, efft:0
# iter 1900 | Loss: 0.0972  time: 0.092  gradnorm: 1.4e-09, fraction:2.1e-07, efft:0
# iter 2000 | Loss: 0.0926  time: 0.09  gradnorm: 1.4e-09, fraction:1.9e-07, efft:0
# (1, 1)
# iter 0 | Loss: 0.991  time: 0.017  gradnorm: 1.2e-10, fraction:5.2e-09, efft:0
# iter 1 | Loss: 1.01  time: 0.01  gradnorm: 1.2e-10, fraction:9.1e-09, efft:0
# iter 2 | Loss: 1.01  time: 0.012  gradnorm: 1.2e-10, fraction:9.3e-09, efft:0
# iter 3 | Loss: 1.01  time: 0.011  gradnorm: 1.2e-10, fraction:9.5e-09, efft:0
# iter 4 | Loss: 1.01  time: 0.011  gradnorm: 1.2e-10, fraction:9.8e-09, efft:0
# iter 100 | Loss: 1.0  time: 0.017  gradnorm: 1.2e-10, fraction:2.3e-08, efft:0
# iter 200 | Loss: 1.0  time: 0.017  gradnorm: 1.2e-10, fraction:4.7e-08, efft:0
# iter 300 | Loss: 1.0  time: 0.017  gradnorm: 1.2e-10, fraction:2.8e-08, efft:0
# iter 400 | Loss: 1.02  time: 0.016  gradnorm: 1.2e-10, fraction:2.7e-08, efft:0
# iter 500 | Loss: 0.993  time: 0.017  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 600 | Loss: 1.0  time: 0.015  gradnorm: 1.2e-10, fraction:2.4e-08, efft:0
# iter 700 | Loss: 0.994  time: 0.016  gradnorm: 1.2e-10, fraction:1.8e-08, efft:0
# iter 800 | Loss: 1.01  time: 0.017  gradnorm: 1.2e-10, fraction:1.7e-08, efft:0
# iter 900 | Loss: 0.994  time: 0.018  gradnorm: 1.2e-10, fraction:2.6e-08, efft:0
# iter 1000 | Loss: 0.998  time: 0.017  gradnorm: 1.2e-10, fraction:1.4e-08, efft:0
# iter 1100 | Loss: 1.0  time: 0.016  gradnorm: 1.2e-10, fraction:1.9e-08, efft:0
# iter 1200 | Loss: 0.994  time: 0.018  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 1300 | Loss: 1.01  time: 0.021  gradnorm: 1.2e-10, fraction:1.5e-08, efft:0
# iter 1400 | Loss: 0.99  time: 0.014  gradnorm: 1.2e-10, fraction:7.9e-09, efft:0
# iter 1500 | Loss: 0.994  time: 0.018  gradnorm: 1.2e-10, fraction:8.9e-09, efft:0
# iter 1600 | Loss: 1.01  time: 0.017  gradnorm: 1.2e-10, fraction:5.9e-09, efft:0
# iter 1700 | Loss: 0.978  time: 0.017  gradnorm: 1.2e-10, fraction:5e-09, efft:0
# iter 1800 | Loss: 0.989  time: 0.016  gradnorm: 1.2e-10, fraction:4.1e-09, efft:0
# iter 1900 | Loss: 0.978  time: 0.015  gradnorm: 1.2e-10, fraction:3.3e-09, efft:0
# iter 2000 | Loss: 0.985  time: 0.02  gradnorm: 1.2e-10, fraction:2.7e-09, efft:0
# (1, 3)
# iter 0 | Loss: 0.998  time: 0.038  gradnorm: 2.9e-10, fraction:5.5e-09, efft:0
# iter 1 | Loss: 1.01  time: 0.039  gradnorm: 2.9e-10, fraction:7.1e-09, efft:0
# iter 2 | Loss: 1.01  time: 0.037  gradnorm: 2.9e-10, fraction:7.3e-09, efft:0
# iter 3 | Loss: 1.01  time: 0.037  gradnorm: 2.9e-10, fraction:7.5e-09, efft:0
# iter 4 | Loss: 1.01  time: 0.041  gradnorm: 2.9e-10, fraction:7.6e-09, efft:0
# iter 100 | Loss: 0.999  time: 0.044  gradnorm: 2.9e-10, fraction:1.3e-08, efft:0
# iter 200 | Loss: 0.992  time: 0.042  gradnorm: 2.9e-10, fraction:6.6e-09, efft:0
# iter 300 | Loss: 0.979  time: 0.047  gradnorm: 2.9e-10, fraction:4.3e-09, efft:0
# iter 400 | Loss: 0.98  time: 0.039  gradnorm: 2.9e-10, fraction:3.2e-09, efft:0
# iter 500 | Loss: 0.936  time: 0.046  gradnorm: 2.9e-10, fraction:2.5e-09, efft:0
# iter 600 | Loss: 0.916  time: 0.047  gradnorm: 2.9e-10, fraction:2e-09, efft:0
# iter 700 | Loss: 0.879  time: 0.045  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 800 | Loss: 0.858  time: 0.041  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 900 | Loss: 0.802  time: 0.039  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1000 | Loss: 0.758  time: 0.04  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1100 | Loss: 0.715  time: 0.043  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1200 | Loss: 0.667  time: 0.041  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1300 | Loss: 0.625  time: 0.041  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1400 | Loss: 0.581  time: 0.039  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1500 | Loss: 0.539  time: 0.042  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1600 | Loss: 0.498  time: 0.044  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1700 | Loss: 0.453  time: 0.039  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 1800 | Loss: 0.425  time: 0.043  gradnorm: 2.9e-10, fraction:1.9e-09, efft:0
# iter 1900 | Loss: 0.39  time: 0.039  gradnorm: 2.9e-10, fraction:2.3e-09, efft:0
# iter 2000 | Loss: 0.367  time: 0.049  gradnorm: 2.9e-10, fraction:3.1e-09, efft:0
# (1, 5)
# iter 0 | Loss: 1.0  time: 0.067  gradnorm: 5.6e-10, fraction:1.2e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.064  gradnorm: 5.6e-10, fraction:4.3e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.066  gradnorm: 5.6e-10, fraction:4.6e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.066  gradnorm: 5.6e-10, fraction:5e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.066  gradnorm: 5.6e-10, fraction:5.5e-08, efft:0
# iter 100 | Loss: 0.998  time: 0.07  gradnorm: 5.6e-10, fraction:4.5e-08, efft:0
# iter 200 | Loss: 0.983  time: 0.07  gradnorm: 5.6e-10, fraction:1.7e-08, efft:0
# iter 300 | Loss: 0.948  time: 0.065  gradnorm: 5.6e-10, fraction:7.5e-09, efft:0
# iter 400 | Loss: 0.906  time: 0.068  gradnorm: 5.6e-10, fraction:4.2e-09, efft:0
# iter 500 | Loss: 0.808  time: 0.067  gradnorm: 5.6e-10, fraction:3.3e-09, efft:0
# iter 600 | Loss: 0.72  time: 0.069  gradnorm: 5.6e-10, fraction:2.8e-09, efft:0
# iter 700 | Loss: 0.624  time: 0.062  gradnorm: 5.6e-10, fraction:2.9e-09, efft:0
# iter 800 | Loss: 0.544  time: 0.066  gradnorm: 5.6e-10, fraction:3.3e-09, efft:0
# iter 900 | Loss: 0.457  time: 0.063  gradnorm: 5.6e-10, fraction:4.7e-09, efft:0
# iter 1000 | Loss: 0.404  time: 0.063  gradnorm: 5.6e-10, fraction:6.1e-09, efft:0
# iter 1100 | Loss: 0.368  time: 0.063  gradnorm: 5.6e-10, fraction:9e-09, efft:0
# iter 1200 | Loss: 0.334  time: 0.063  gradnorm: 5.6e-10, fraction:1.6e-08, efft:0
# iter 1300 | Loss: 0.323  time: 0.065  gradnorm: 5.6e-10, fraction:2.1e-08, efft:0
# iter 1400 | Loss: 0.308  time: 0.065  gradnorm: 5.6e-10, fraction:2e-08, efft:0
# iter 1500 | Loss: 0.298  time: 0.07  gradnorm: 5.6e-10, fraction:2.7e-08, efft:0
# iter 1600 | Loss: 0.285  time: 0.072  gradnorm: 5.6e-10, fraction:2.2e-08, efft:0
# iter 1700 | Loss: 0.263  time: 0.075  gradnorm: 5.6e-10, fraction:2.6e-08, efft:0
# iter 1800 | Loss: 0.25  time: 0.074  gradnorm: 5.6e-10, fraction:2.5e-08, efft:0
# iter 1900 | Loss: 0.23  time: 0.069  gradnorm: 5.6e-10, fraction:2.1e-08, efft:0
# iter 2000 | Loss: 0.214  time: 0.069  gradnorm: 5.6e-10, fraction:2.4e-08, efft:0
# (1, 7)
# iter 0 | Loss: 1.02  time: 0.091  gradnorm: 1.4e-09, fraction:1.2e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.09  gradnorm: 1.4e-09, fraction:4.3e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.087  gradnorm: 1.4e-09, fraction:5.5e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.088  gradnorm: 1.4e-09, fraction:7.5e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.088  gradnorm: 1.4e-09, fraction:1.1e-07, efft:0
# iter 100 | Loss: 0.963  time: 0.096  gradnorm: 1.4e-09, fraction:1.7e-08, efft:0
# iter 200 | Loss: 0.793  time: 0.096  gradnorm: 1.4e-09, fraction:6.8e-09, efft:0
# iter 300 | Loss: 0.573  time: 0.1  gradnorm: 1.4e-09, fraction:1.1e-08, efft:0
# iter 400 | Loss: 0.422  time: 0.093  gradnorm: 1.4e-09, fraction:1.4e-08, efft:0
# iter 500 | Loss: 0.333  time: 0.094  gradnorm: 1.4e-09, fraction:2.6e-08, efft:0
# iter 600 | Loss: 0.299  time: 0.1  gradnorm: 1.4e-09, fraction:6.2e-08, efft:0
# iter 700 | Loss: 0.278  time: 0.1  gradnorm: 1.4e-09, fraction:3.9e-08, efft:0
# iter 800 | Loss: 0.262  time: 0.095  gradnorm: 1.4e-09, fraction:7.4e-08, efft:0
# iter 900 | Loss: 0.246  time: 0.098  gradnorm: 1.4e-09, fraction:5.7e-08, efft:0
# iter 1000 | Loss: 0.227  time: 0.098  gradnorm: 1.4e-09, fraction:9.2e-08, efft:0
# iter 1100 | Loss: 0.213  time: 0.1  gradnorm: 1.4e-09, fraction:1.2e-07, efft:0
# iter 1200 | Loss: 0.19  time: 0.099  gradnorm: 1.4e-09, fraction:1.1e-07, efft:0
# iter 1300 | Loss: 0.172  time: 0.1  gradnorm: 1.4e-09, fraction:9e-08, efft:0
# iter 1400 | Loss: 0.155  time: 0.1  gradnorm: 1.4e-09, fraction:9.8e-08, efft:0
# iter 1500 | Loss: 0.137  time: 0.098  gradnorm: 1.4e-09, fraction:1.2e-07, efft:0
# iter 1600 | Loss: 0.123  time: 0.098  gradnorm: 1.4e-09, fraction:1.6e-07, efft:0
# iter 1700 | Loss: 0.113  time: 0.1  gradnorm: 1.4e-09, fraction:1.7e-07, efft:0
# iter 1800 | Loss: 0.104  time: 0.1  gradnorm: 1.4e-09, fraction:2e-07, efft:0
# iter 1900 | Loss: 0.0987  time: 0.1  gradnorm: 1.4e-09, fraction:1.6e-07, efft:0
# iter 2000 | Loss: 0.0921  time: 0.089  gradnorm: 1.4e-09, fraction:1.7e-07, efft:0
# (2, 1)
# iter 0 | Loss: 1.0  time: 0.016  gradnorm: 1.2e-10, fraction:6.9e-09, efft:0
# iter 1 | Loss: 0.997  time: 0.011  gradnorm: 1.2e-10, fraction:8.4e-09, efft:0
# iter 2 | Loss: 0.997  time: 0.01  gradnorm: 1.2e-10, fraction:8.6e-09, efft:0
# iter 3 | Loss: 0.997  time: 0.01  gradnorm: 1.2e-10, fraction:8.7e-09, efft:0
# iter 4 | Loss: 0.997  time: 0.01  gradnorm: 1.2e-10, fraction:8.9e-09, efft:0
# iter 100 | Loss: 1.0  time: 0.015  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 200 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:1.5e-08, efft:0
# iter 300 | Loss: 1.0  time: 0.015  gradnorm: 1.2e-10, fraction:7.2e-09, efft:0
# iter 400 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:1.5e-08, efft:0
# iter 500 | Loss: 0.993  time: 0.014  gradnorm: 1.2e-10, fraction:1.3e-08, efft:0
# iter 600 | Loss: 1.01  time: 0.014  gradnorm: 1.2e-10, fraction:1.7e-08, efft:0
# iter 700 | Loss: 1.0  time: 0.016  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 800 | Loss: 0.991  time: 0.014  gradnorm: 1.2e-10, fraction:9.3e-09, efft:0
# iter 900 | Loss: 0.991  time: 0.014  gradnorm: 1.2e-10, fraction:5.9e-09, efft:0
# iter 1000 | Loss: 0.993  time: 0.014  gradnorm: 1.2e-10, fraction:5.5e-09, efft:0
# iter 1100 | Loss: 0.981  time: 0.015  gradnorm: 1.2e-10, fraction:4.3e-09, efft:0
# iter 1200 | Loss: 0.993  time: 0.015  gradnorm: 1.2e-10, fraction:3.7e-09, efft:0
# iter 1300 | Loss: 0.968  time: 0.014  gradnorm: 1.2e-10, fraction:3.1e-09, efft:0
# iter 1400 | Loss: 0.978  time: 0.015  gradnorm: 1.2e-10, fraction:2.7e-09, efft:0
# iter 1500 | Loss: 0.955  time: 0.016  gradnorm: 1.2e-10, fraction:2.1e-09, efft:0
# iter 1600 | Loss: 0.958  time: 0.014  gradnorm: 1.2e-10, fraction:1.9e-09, efft:0
# iter 1700 | Loss: 0.958  time: 0.014  gradnorm: 1.2e-10, fraction:1.6e-09, efft:0
# iter 1800 | Loss: 0.962  time: 0.015  gradnorm: 1.2e-10, fraction:1.5e-09, efft:0
# iter 1900 | Loss: 0.933  time: 0.014  gradnorm: 1.2e-10, fraction:1.3e-09, efft:0
# iter 2000 | Loss: 0.92  time: 0.014  gradnorm: 1.2e-10, fraction:1.3e-09, efft:0
# (2, 3)
# iter 0 | Loss: 1.01  time: 0.039  gradnorm: 2.9e-10, fraction:5.9e-09, efft:0
# iter 1 | Loss: 1.0  time: 0.034  gradnorm: 2.9e-10, fraction:4.9e-09, efft:0
# iter 2 | Loss: 1.0  time: 0.034  gradnorm: 2.9e-10, fraction:5e-09, efft:0
# iter 3 | Loss: 1.0  time: 0.035  gradnorm: 2.9e-10, fraction:5.1e-09, efft:0
# iter 4 | Loss: 1.0  time: 0.035  gradnorm: 2.9e-10, fraction:5.2e-09, efft:0
# iter 100 | Loss: 1.0  time: 0.038  gradnorm: 2.9e-10, fraction:1.9e-08, efft:0
# iter 200 | Loss: 0.993  time: 0.038  gradnorm: 2.9e-10, fraction:8.4e-09, efft:0
# iter 300 | Loss: 0.984  time: 0.039  gradnorm: 2.9e-10, fraction:4.7e-09, efft:0
# iter 400 | Loss: 0.966  time: 0.038  gradnorm: 2.9e-10, fraction:3.7e-09, efft:0
# iter 500 | Loss: 0.934  time: 0.04  gradnorm: 2.9e-10, fraction:2.7e-09, efft:0
# iter 600 | Loss: 0.917  time: 0.039  gradnorm: 2.9e-10, fraction:2.2e-09, efft:0
# iter 700 | Loss: 0.875  time: 0.04  gradnorm: 2.9e-10, fraction:1.8e-09, efft:0
# iter 800 | Loss: 0.825  time: 0.042  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 900 | Loss: 0.78  time: 0.039  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1000 | Loss: 0.732  time: 0.039  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1100 | Loss: 0.674  time: 0.043  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1200 | Loss: 0.632  time: 0.047  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1300 | Loss: 0.57  time: 0.041  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1400 | Loss: 0.529  time: 0.042  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 1500 | Loss: 0.486  time: 0.041  gradnorm: 2.9e-10, fraction:2e-09, efft:0
# iter 1600 | Loss: 0.458  time: 0.046  gradnorm: 2.9e-10, fraction:2.4e-09, efft:0
# iter 1700 | Loss: 0.429  time: 0.042  gradnorm: 2.9e-10, fraction:3.1e-09, efft:0
# iter 1800 | Loss: 0.411  time: 0.045  gradnorm: 2.9e-10, fraction:3.7e-09, efft:0
# iter 1900 | Loss: 0.38  time: 0.044  gradnorm: 2.9e-10, fraction:4e-09, efft:0
# iter 2000 | Loss: 0.366  time: 0.043  gradnorm: 2.9e-10, fraction:5.2e-09, efft:0
# (2, 5)
# iter 0 | Loss: 1.02  time: 0.07  gradnorm: 5.6e-10, fraction:6e-09, efft:0
# iter 1 | Loss: 1.0  time: 0.063  gradnorm: 5.6e-10, fraction:7.9e-09, efft:0
# iter 2 | Loss: 1.0  time: 0.069  gradnorm: 5.6e-10, fraction:8.1e-09, efft:0
# iter 3 | Loss: 1.0  time: 0.067  gradnorm: 5.6e-10, fraction:8.3e-09, efft:0
# iter 4 | Loss: 1.0  time: 0.066  gradnorm: 5.6e-10, fraction:8.5e-09, efft:0
# iter 100 | Loss: 0.999  time: 0.072  gradnorm: 5.6e-10, fraction:7.8e-08, efft:0
# iter 200 | Loss: 0.989  time: 0.074  gradnorm: 5.6e-10, fraction:3.5e-08, efft:0
# iter 300 | Loss: 0.969  time: 0.069  gradnorm: 5.6e-10, fraction:9.1e-09, efft:0
# iter 400 | Loss: 0.932  time: 0.072  gradnorm: 5.6e-10, fraction:5.5e-09, efft:0
# iter 500 | Loss: 0.867  time: 0.071  gradnorm: 5.6e-10, fraction:3.7e-09, efft:0
# iter 600 | Loss: 0.807  time: 0.072  gradnorm: 5.6e-10, fraction:2.9e-09, efft:0
# iter 700 | Loss: 0.714  time: 0.068  gradnorm: 5.6e-10, fraction:2.6e-09, efft:0
# iter 800 | Loss: 0.621  time: 0.07  gradnorm: 5.6e-10, fraction:2.8e-09, efft:0
# iter 900 | Loss: 0.539  time: 0.072  gradnorm: 5.6e-10, fraction:3.2e-09, efft:0
# iter 1000 | Loss: 0.469  time: 0.067  gradnorm: 5.6e-10, fraction:4.5e-09, efft:0
# iter 1100 | Loss: 0.42  time: 0.071  gradnorm: 5.6e-10, fraction:6.2e-09, efft:0
# iter 1200 | Loss: 0.376  time: 0.074  gradnorm: 5.6e-10, fraction:8.3e-09, efft:0
# iter 1300 | Loss: 0.339  time: 0.07  gradnorm: 5.6e-10, fraction:1.2e-08, efft:0
# iter 1400 | Loss: 0.327  time: 0.072  gradnorm: 5.6e-10, fraction:1.3e-08, efft:0
# iter 1500 | Loss: 0.305  time: 0.07  gradnorm: 5.6e-10, fraction:2.3e-08, efft:0
# iter 1600 | Loss: 0.294  time: 0.072  gradnorm: 5.6e-10, fraction:2.2e-08, efft:0
# iter 1700 | Loss: 0.282  time: 0.076  gradnorm: 5.6e-10, fraction:2.9e-08, efft:0
# iter 1800 | Loss: 0.271  time: 0.072  gradnorm: 5.6e-10, fraction:2.2e-08, efft:0
# iter 1900 | Loss: 0.251  time: 0.07  gradnorm: 5.6e-10, fraction:2.3e-08, efft:0
# iter 2000 | Loss: 0.239  time: 0.071  gradnorm: 5.6e-10, fraction:2.5e-08, efft:0
# (2, 7)
# iter 0 | Loss: 1.02  time: 0.099  gradnorm: 1.4e-09, fraction:1.9e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.096  gradnorm: 1.4e-09, fraction:2e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.093  gradnorm: 1.4e-09, fraction:2e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.097  gradnorm: 1.4e-09, fraction:2.1e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.091  gradnorm: 1.4e-09, fraction:2.2e-08, efft:0
# iter 100 | Loss: 0.981  time: 0.096  gradnorm: 1.4e-09, fraction:2.1e-08, efft:0
# iter 200 | Loss: 0.858  time: 0.098  gradnorm: 1.4e-09, fraction:7.3e-09, efft:0
# iter 300 | Loss: 0.662  time: 0.093  gradnorm: 1.4e-09, fraction:8e-09, efft:0
# iter 400 | Loss: 0.516  time: 0.093  gradnorm: 1.4e-09, fraction:1.1e-08, efft:0
# iter 500 | Loss: 0.367  time: 0.098  gradnorm: 1.4e-09, fraction:1.3e-08, efft:0
# iter 600 | Loss: 0.312  time: 0.093  gradnorm: 1.4e-09, fraction:3.9e-08, efft:0
# iter 700 | Loss: 0.272  time: 0.093  gradnorm: 1.4e-09, fraction:5.1e-08, efft:0
# iter 800 | Loss: 0.238  time: 0.098  gradnorm: 1.4e-09, fraction:4.7e-08, efft:0
# iter 900 | Loss: 0.211  time: 0.099  gradnorm: 1.4e-09, fraction:8.6e-08, efft:0
# iter 1000 | Loss: 0.191  time: 0.089  gradnorm: 1.4e-09, fraction:6.2e-08, efft:0
# iter 1100 | Loss: 0.175  time: 0.089  gradnorm: 1.4e-09, fraction:6.6e-08, efft:0
# iter 1200 | Loss: 0.157  time: 0.091  gradnorm: 1.4e-09, fraction:7.3e-08, efft:0
# iter 1300 | Loss: 0.136  time: 0.091  gradnorm: 1.4e-09, fraction:8e-08, efft:0
# iter 1400 | Loss: 0.126  time: 0.086  gradnorm: 1.4e-09, fraction:6.4e-08, efft:0
# iter 1500 | Loss: 0.118  time: 0.099  gradnorm: 1.4e-09, fraction:1.3e-07, efft:0
# iter 1600 | Loss: 0.109  time: 0.1  gradnorm: 1.4e-09, fraction:1.1e-07, efft:0
# iter 1700 | Loss: 0.108  time: 0.091  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 1800 | Loss: 0.101  time: 0.093  gradnorm: 1.4e-09, fraction:9.9e-08, efft:0
# iter 1900 | Loss: 0.0936  time: 0.099  gradnorm: 1.4e-09, fraction:1.8e-07, efft:0
# iter 2000 | Loss: 0.0908  time: 0.099  gradnorm: 1.4e-09, fraction:1.1e-07, efft:0
# lr: 0.1
# (0, 1)
# iter 0 | Loss: 0.989  time: 0.018  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 1 | Loss: 0.996  time: 0.011  gradnorm: 1.2e-10, fraction:5.9e-08, efft:0
# iter 2 | Loss: 0.996  time: 0.013  gradnorm: 1.2e-10, fraction:6e-08, efft:0
# iter 3 | Loss: 0.996  time: 0.015  gradnorm: 1.2e-10, fraction:6.1e-08, efft:0
# iter 4 | Loss: 0.996  time: 0.013  gradnorm: 1.2e-10, fraction:6.3e-08, efft:0
# iter 100 | Loss: 0.988  time: 0.017  gradnorm: 1.2e-10, fraction:2.7e-08, efft:0
# iter 200 | Loss: 1.01  time: 0.022  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 300 | Loss: 1.0  time: 0.02  gradnorm: 1.2e-10, fraction:6.5e-09, efft:0
# iter 400 | Loss: 0.981  time: 0.017  gradnorm: 1.2e-10, fraction:4.6e-09, efft:0
# iter 500 | Loss: 0.993  time: 0.016  gradnorm: 1.2e-10, fraction:3.3e-09, efft:0
# iter 600 | Loss: 0.988  time: 0.018  gradnorm: 1.2e-10, fraction:2.6e-09, efft:0
# iter 700 | Loss: 0.976  time: 0.022  gradnorm: 1.2e-10, fraction:2.2e-09, efft:0
# iter 800 | Loss: 0.972  time: 0.018  gradnorm: 1.2e-10, fraction:1.8e-09, efft:0
# iter 900 | Loss: 0.957  time: 0.016  gradnorm: 1.2e-10, fraction:1.5e-09, efft:0
# iter 1000 | Loss: 0.952  time: 0.016  gradnorm: 1.2e-10, fraction:1.3e-09, efft:0
# iter 1100 | Loss: 0.937  time: 0.016  gradnorm: 1.2e-10, fraction:1.1e-09, efft:0
# iter 1200 | Loss: 0.933  time: 0.017  gradnorm: 1.2e-10, fraction:9.6e-10, efft:0
# iter 1300 | Loss: 0.906  time: 0.016  gradnorm: 1.2e-10, fraction:8.8e-10, efft:0
# iter 1400 | Loss: 0.887  time: 0.016  gradnorm: 1.2e-10, fraction:8e-10, efft:0
# iter 1500 | Loss: 0.88  time: 0.015  gradnorm: 1.2e-10, fraction:7.4e-10, efft:0
# iter 1600 | Loss: 0.846  time: 0.017  gradnorm: 1.2e-10, fraction:7e-10, efft:0
# iter 1700 | Loss: 0.82  time: 0.014  gradnorm: 1.2e-10, fraction:6.5e-10, efft:0
# iter 1800 | Loss: 0.805  time: 0.017  gradnorm: 1.2e-10, fraction:6.1e-10, efft:0
# iter 1900 | Loss: 0.769  time: 0.016  gradnorm: 1.2e-10, fraction:6e-10, efft:0
# iter 2000 | Loss: 0.748  time: 0.017  gradnorm: 1.2e-10, fraction:6e-10, efft:0
# (0, 3)
# iter 0 | Loss: 0.989  time: 0.039  gradnorm: 2.9e-10, fraction:3.5e-08, efft:0
# iter 1 | Loss: 0.997  time: 0.036  gradnorm: 2.9e-10, fraction:5.9e-08, efft:0
# iter 2 | Loss: 0.997  time: 0.037  gradnorm: 2.9e-10, fraction:6.1e-08, efft:0
# iter 3 | Loss: 0.997  time: 0.037  gradnorm: 2.9e-10, fraction:6.2e-08, efft:0
# iter 4 | Loss: 0.997  time: 0.036  gradnorm: 2.9e-10, fraction:6.4e-08, efft:0
# iter 100 | Loss: 0.987  time: 0.039  gradnorm: 2.9e-10, fraction:3.6e-08, efft:0
# iter 200 | Loss: 1.0  time: 0.041  gradnorm: 2.9e-10, fraction:1.2e-08, efft:0
# iter 300 | Loss: 0.99  time: 0.043  gradnorm: 2.9e-10, fraction:6.8e-09, efft:0
# iter 400 | Loss: 0.957  time: 0.04  gradnorm: 2.9e-10, fraction:4.5e-09, efft:0
# iter 500 | Loss: 0.951  time: 0.039  gradnorm: 2.9e-10, fraction:3.2e-09, efft:0
# iter 600 | Loss: 0.922  time: 0.041  gradnorm: 2.9e-10, fraction:2.4e-09, efft:0
# iter 700 | Loss: 0.883  time: 0.038  gradnorm: 2.9e-10, fraction:2e-09, efft:0
# iter 800 | Loss: 0.847  time: 0.041  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 900 | Loss: 0.794  time: 0.041  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 1000 | Loss: 0.748  time: 0.042  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1100 | Loss: 0.685  time: 0.039  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1200 | Loss: 0.629  time: 0.039  gradnorm: 2.9e-10, fraction:1.2e-09, efft:0
# iter 1300 | Loss: 0.564  time: 0.038  gradnorm: 2.9e-10, fraction:1.2e-09, efft:0
# iter 1400 | Loss: 0.504  time: 0.039  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1500 | Loss: 0.453  time: 0.038  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1600 | Loss: 0.394  time: 0.039  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 1700 | Loss: 0.348  time: 0.039  gradnorm: 2.9e-10, fraction:1.8e-09, efft:0
# iter 1800 | Loss: 0.305  time: 0.037  gradnorm: 2.9e-10, fraction:2.3e-09, efft:0
# iter 1900 | Loss: 0.274  time: 0.039  gradnorm: 2.9e-10, fraction:3e-09, efft:0
# iter 2000 | Loss: 0.253  time: 0.038  gradnorm: 2.9e-10, fraction:4.6e-09, efft:0
# (0, 5)
# iter 0 | Loss: 0.989  time: 0.063  gradnorm: 5.6e-10, fraction:3.2e-08, efft:0
# iter 1 | Loss: 0.996  time: 0.061  gradnorm: 5.6e-10, fraction:7.3e-08, efft:0
# iter 2 | Loss: 0.996  time: 0.061  gradnorm: 5.6e-10, fraction:7.1e-08, efft:0
# iter 3 | Loss: 0.996  time: 0.062  gradnorm: 5.6e-10, fraction:6.9e-08, efft:0
# iter 4 | Loss: 0.996  time: 0.061  gradnorm: 5.6e-10, fraction:6.6e-08, efft:0
# iter 100 | Loss: 0.976  time: 0.064  gradnorm: 5.6e-10, fraction:1.3e-08, efft:0
# iter 200 | Loss: 0.963  time: 0.063  gradnorm: 5.6e-10, fraction:6.2e-09, efft:0
# iter 300 | Loss: 0.906  time: 0.063  gradnorm: 5.6e-10, fraction:4e-09, efft:0
# iter 400 | Loss: 0.812  time: 0.062  gradnorm: 5.6e-10, fraction:3.1e-09, efft:0
# iter 500 | Loss: 0.723  time: 0.064  gradnorm: 5.6e-10, fraction:2.5e-09, efft:0
# iter 600 | Loss: 0.614  time: 0.065  gradnorm: 5.6e-10, fraction:2.5e-09, efft:0
# iter 700 | Loss: 0.509  time: 0.072  gradnorm: 5.6e-10, fraction:2.8e-09, efft:0
# iter 800 | Loss: 0.409  time: 0.066  gradnorm: 5.6e-10, fraction:3.6e-09, efft:0
# iter 900 | Loss: 0.329  time: 0.072  gradnorm: 5.6e-10, fraction:6.3e-09, efft:0
# iter 1000 | Loss: 0.279  time: 0.071  gradnorm: 5.6e-10, fraction:1.3e-08, efft:0
# iter 1100 | Loss: 0.245  time: 0.068  gradnorm: 5.6e-10, fraction:1.6e-08, efft:0
# iter 1200 | Loss: 0.219  time: 0.069  gradnorm: 5.6e-10, fraction:2.6e-08, efft:0
# iter 1300 | Loss: 0.19  time: 0.068  gradnorm: 5.6e-10, fraction:3.2e-08, efft:0
# iter 1400 | Loss: 0.166  time: 0.073  gradnorm: 5.6e-10, fraction:3.6e-08, efft:0
# iter 1500 | Loss: 0.15  time: 0.073  gradnorm: 5.6e-10, fraction:3.5e-08, efft:0
# iter 1600 | Loss: 0.128  time: 0.066  gradnorm: 5.6e-10, fraction:4.4e-08, efft:0
# iter 1700 | Loss: 0.112  time: 0.076  gradnorm: 5.6e-10, fraction:5e-08, efft:0
# iter 1800 | Loss: 0.0986  time: 0.073  gradnorm: 5.6e-10, fraction:6e-08, efft:0
# iter 1900 | Loss: 0.085  time: 0.07  gradnorm: 5.6e-10, fraction:6.2e-08, efft:0
# iter 2000 | Loss: 0.0715  time: 0.073  gradnorm: 5.6e-10, fraction:5.4e-08, efft:0
# (0, 7)
# iter 0 | Loss: 0.988  time: 0.095  gradnorm: 1.4e-09, fraction:1.2e-07, efft:0
# iter 1 | Loss: 0.996  time: 0.097  gradnorm: 1.4e-09, fraction:2.5e-07, efft:0
# iter 2 | Loss: 0.996  time: 0.093  gradnorm: 1.4e-09, fraction:2.3e-07, efft:0
# iter 3 | Loss: 0.996  time: 0.089  gradnorm: 1.4e-09, fraction:2.1e-07, efft:0
# iter 4 | Loss: 0.996  time: 0.096  gradnorm: 1.4e-09, fraction:1.9e-07, efft:0
# iter 100 | Loss: 0.923  time: 0.094  gradnorm: 1.4e-09, fraction:1.3e-08, efft:0
# iter 200 | Loss: 0.736  time: 0.098  gradnorm: 1.4e-09, fraction:6.7e-09, efft:0
# iter 300 | Loss: 0.484  time: 0.1  gradnorm: 1.4e-09, fraction:8.7e-09, efft:0
# iter 400 | Loss: 0.299  time: 0.098  gradnorm: 1.4e-09, fraction:2.4e-08, efft:0
# iter 500 | Loss: 0.235  time: 0.098  gradnorm: 1.4e-09, fraction:1e-07, efft:0
# iter 600 | Loss: 0.18  time: 0.1  gradnorm: 1.4e-09, fraction:7.9e-08, efft:0
# iter 700 | Loss: 0.128  time: 0.094  gradnorm: 1.4e-09, fraction:7.1e-08, efft:0
# iter 800 | Loss: 0.0895  time: 0.094  gradnorm: 1.4e-09, fraction:1.5e-07, efft:0
# iter 900 | Loss: 0.0637  time: 0.095  gradnorm: 1.4e-09, fraction:2.2e-07, efft:0
# iter 1000 | Loss: 0.0453  time: 0.094  gradnorm: 1.4e-09, fraction:2.9e-07, efft:0
# iter 1100 | Loss: 0.0316  time: 0.094  gradnorm: 1.4e-09, fraction:3.3e-07, efft:0
# iter 1200 | Loss: 0.0223  time: 0.094  gradnorm: 1.4e-09, fraction:4.7e-07, efft:0
# iter 1300 | Loss: 0.0152  time: 0.095  gradnorm: 1.4e-09, fraction:8.4e-07, efft:0
# iter 1400 | Loss: 0.0105  time: 0.1  gradnorm: 1.4e-09, fraction:1.1e-06, efft:0
# iter 1500 | Loss: 0.00846  time: 0.094  gradnorm: 1.4e-09, fraction:1.6e-06, efft:0
# iter 1600 | Loss: 0.00619  time: 0.096  gradnorm: 1.4e-09, fraction:2e-06, efft:0
# iter 1700 | Loss: 0.005  time: 0.098  gradnorm: 1.4e-09, fraction:1.9e-06, efft:0
# iter 1800 | Loss: 0.00407  time: 0.098  gradnorm: 1.4e-09, fraction:3.1e-06, efft:0
# iter 1900 | Loss: 0.00307  time: 0.093  gradnorm: 1.4e-09, fraction:2.6e-06, efft:0
# iter 2000 | Loss: 0.00309  time: 0.1  gradnorm: 1.4e-09, fraction:2.1e-06, efft:0
# (1, 1)
# iter 0 | Loss: 0.989  time: 0.017  gradnorm: 1.2e-10, fraction:1.5e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.013  gradnorm: 1.2e-10, fraction:2.4e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.011  gradnorm: 1.2e-10, fraction:2.4e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.01  gradnorm: 1.2e-10, fraction:2.4e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.011  gradnorm: 1.2e-10, fraction:2.5e-08, efft:0
# iter 100 | Loss: 1.0  time: 0.017  gradnorm: 1.2e-10, fraction:2.2e-08, efft:0
# iter 200 | Loss: 1.0  time: 0.015  gradnorm: 1.2e-10, fraction:9.8e-09, efft:0
# iter 300 | Loss: 0.996  time: 0.016  gradnorm: 1.2e-10, fraction:6.1e-09, efft:0
# iter 400 | Loss: 1.01  time: 0.018  gradnorm: 1.2e-10, fraction:4.2e-09, efft:0
# iter 500 | Loss: 0.982  time: 0.014  gradnorm: 1.2e-10, fraction:3.2e-09, efft:0
# iter 600 | Loss: 0.984  time: 0.017  gradnorm: 1.2e-10, fraction:2.5e-09, efft:0
# iter 700 | Loss: 0.971  time: 0.015  gradnorm: 1.2e-10, fraction:2e-09, efft:0
# iter 800 | Loss: 0.983  time: 0.015  gradnorm: 1.2e-10, fraction:1.7e-09, efft:0
# iter 900 | Loss: 0.954  time: 0.017  gradnorm: 1.2e-10, fraction:1.4e-09, efft:0
# iter 1000 | Loss: 0.946  time: 0.017  gradnorm: 1.2e-10, fraction:1.2e-09, efft:0
# iter 1100 | Loss: 0.936  time: 0.017  gradnorm: 1.2e-10, fraction:1.1e-09, efft:0
# iter 1200 | Loss: 0.914  time: 0.016  gradnorm: 1.2e-10, fraction:9.6e-10, efft:0
# iter 1300 | Loss: 0.909  time: 0.015  gradnorm: 1.2e-10, fraction:8.6e-10, efft:0
# iter 1400 | Loss: 0.881  time: 0.015  gradnorm: 1.2e-10, fraction:8.1e-10, efft:0
# iter 1500 | Loss: 0.867  time: 0.019  gradnorm: 1.2e-10, fraction:7.6e-10, efft:0
# iter 1600 | Loss: 0.858  time: 0.019  gradnorm: 1.2e-10, fraction:6.8e-10, efft:0
# iter 1700 | Loss: 0.811  time: 0.018  gradnorm: 1.2e-10, fraction:6.7e-10, efft:0
# iter 1800 | Loss: 0.797  time: 0.016  gradnorm: 1.2e-10, fraction:6.3e-10, efft:0
# iter 1900 | Loss: 0.771  time: 0.016  gradnorm: 1.2e-10, fraction:6.2e-10, efft:0
# iter 2000 | Loss: 0.752  time: 0.015  gradnorm: 1.2e-10, fraction:6e-10, efft:0
# (1, 3)
# iter 0 | Loss: 0.988  time: 0.041  gradnorm: 2.9e-10, fraction:2.3e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.036  gradnorm: 2.9e-10, fraction:2.8e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.036  gradnorm: 2.9e-10, fraction:2.8e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.036  gradnorm: 2.9e-10, fraction:2.7e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.035  gradnorm: 2.9e-10, fraction:2.7e-08, efft:0
# iter 100 | Loss: 0.997  time: 0.044  gradnorm: 2.9e-10, fraction:1.1e-08, efft:0
# iter 200 | Loss: 0.987  time: 0.041  gradnorm: 2.9e-10, fraction:6e-09, efft:0
# iter 300 | Loss: 0.97  time: 0.038  gradnorm: 2.9e-10, fraction:4.1e-09, efft:0
# iter 400 | Loss: 0.964  time: 0.038  gradnorm: 2.9e-10, fraction:3e-09, efft:0
# iter 500 | Loss: 0.914  time: 0.039  gradnorm: 2.9e-10, fraction:2.3e-09, efft:0
# iter 600 | Loss: 0.885  time: 0.04  gradnorm: 2.9e-10, fraction:1.9e-09, efft:0
# iter 700 | Loss: 0.84  time: 0.042  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 800 | Loss: 0.808  time: 0.038  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 900 | Loss: 0.744  time: 0.039  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 1000 | Loss: 0.69  time: 0.039  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1100 | Loss: 0.638  time: 0.039  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1200 | Loss: 0.576  time: 0.039  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 1300 | Loss: 0.524  time: 0.04  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 1400 | Loss: 0.469  time: 0.037  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 1500 | Loss: 0.418  time: 0.037  gradnorm: 2.9e-10, fraction:1.8e-09, efft:0
# iter 1600 | Loss: 0.373  time: 0.038  gradnorm: 2.9e-10, fraction:1.9e-09, efft:0
# iter 1700 | Loss: 0.324  time: 0.04  gradnorm: 2.9e-10, fraction:2.4e-09, efft:0
# iter 1800 | Loss: 0.292  time: 0.039  gradnorm: 2.9e-10, fraction:3.1e-09, efft:0
# iter 1900 | Loss: 0.262  time: 0.038  gradnorm: 2.9e-10, fraction:3.9e-09, efft:0
# iter 2000 | Loss: 0.239  time: 0.038  gradnorm: 2.9e-10, fraction:4.9e-09, efft:0
# (1, 5)
# iter 0 | Loss: 0.99  time: 0.068  gradnorm: 5.6e-10, fraction:3.4e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.065  gradnorm: 5.6e-10, fraction:5.4e-08, efft:0
# iter 2 | Loss: 1.01  time: 0.063  gradnorm: 5.6e-10, fraction:5.5e-08, efft:0
# iter 3 | Loss: 1.01  time: 0.063  gradnorm: 5.6e-10, fraction:5.7e-08, efft:0
# iter 4 | Loss: 1.01  time: 0.062  gradnorm: 5.6e-10, fraction:5.8e-08, efft:0
# iter 100 | Loss: 0.994  time: 0.062  gradnorm: 5.6e-10, fraction:2.4e-08, efft:0
# iter 200 | Loss: 0.968  time: 0.062  gradnorm: 5.6e-10, fraction:9.2e-09, efft:0
# iter 300 | Loss: 0.917  time: 0.072  gradnorm: 5.6e-10, fraction:5.2e-09, efft:0
# iter 400 | Loss: 0.862  time: 0.075  gradnorm: 5.6e-10, fraction:3.6e-09, efft:0
# iter 500 | Loss: 0.748  time: 0.074  gradnorm: 5.6e-10, fraction:3e-09, efft:0
# iter 600 | Loss: 0.652  time: 0.071  gradnorm: 5.6e-10, fraction:3e-09, efft:0
# iter 700 | Loss: 0.547  time: 0.073  gradnorm: 5.6e-10, fraction:3.1e-09, efft:0
# iter 800 | Loss: 0.454  time: 0.07  gradnorm: 5.6e-10, fraction:3.2e-09, efft:0
# iter 900 | Loss: 0.357  time: 0.072  gradnorm: 5.6e-10, fraction:4e-09, efft:0
# iter 1000 | Loss: 0.285  time: 0.067  gradnorm: 5.6e-10, fraction:5.8e-09, efft:0
# iter 1100 | Loss: 0.244  time: 0.063  gradnorm: 5.6e-10, fraction:1.3e-08, efft:0
# iter 1200 | Loss: 0.214  time: 0.064  gradnorm: 5.6e-10, fraction:2.3e-08, efft:0
# iter 1300 | Loss: 0.19  time: 0.062  gradnorm: 5.6e-10, fraction:2.3e-08, efft:0
# iter 1400 | Loss: 0.166  time: 0.062  gradnorm: 5.6e-10, fraction:2.4e-08, efft:0
# iter 1500 | Loss: 0.144  time: 0.063  gradnorm: 5.6e-10, fraction:3e-08, efft:0
# iter 1600 | Loss: 0.122  time: 0.064  gradnorm: 5.6e-10, fraction:4.1e-08, efft:0
# iter 1700 | Loss: 0.105  time: 0.068  gradnorm: 5.6e-10, fraction:4.8e-08, efft:0
# iter 1800 | Loss: 0.0929  time: 0.069  gradnorm: 5.6e-10, fraction:5.3e-08, efft:0
# iter 1900 | Loss: 0.0766  time: 0.067  gradnorm: 5.6e-10, fraction:5.3e-08, efft:0
# iter 2000 | Loss: 0.0649  time: 0.075  gradnorm: 5.6e-10, fraction:5.2e-08, efft:0
# (1, 7)
# iter 0 | Loss: 0.991  time: 0.095  gradnorm: 1.4e-09, fraction:9.7e-08, efft:0
# iter 1 | Loss: 1.01  time: 0.091  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 2 | Loss: 1.01  time: 0.091  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 3 | Loss: 1.01  time: 0.094  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 4 | Loss: 1.01  time: 0.095  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 100 | Loss: 0.938  time: 0.099  gradnorm: 1.4e-09, fraction:1.3e-08, efft:0
# iter 200 | Loss: 0.733  time: 0.091  gradnorm: 1.4e-09, fraction:6.5e-09, efft:0
# iter 300 | Loss: 0.492  time: 0.092  gradnorm: 1.4e-09, fraction:1e-08, efft:0
# iter 400 | Loss: 0.311  time: 0.097  gradnorm: 1.4e-09, fraction:1.7e-08, efft:0
# iter 500 | Loss: 0.236  time: 0.09  gradnorm: 1.4e-09, fraction:8.8e-08, efft:0
# iter 600 | Loss: 0.186  time: 0.093  gradnorm: 1.4e-09, fraction:6.1e-08, efft:0
# iter 700 | Loss: 0.126  time: 0.09  gradnorm: 1.4e-09, fraction:1.2e-07, efft:0
# iter 800 | Loss: 0.0921  time: 0.092  gradnorm: 1.4e-09, fraction:1.9e-07, efft:0
# iter 900 | Loss: 0.0659  time: 0.093  gradnorm: 1.4e-09, fraction:2.2e-07, efft:0
# iter 1000 | Loss: 0.0473  time: 0.087  gradnorm: 1.4e-09, fraction:2.6e-07, efft:0
# iter 1100 | Loss: 0.0348  time: 0.087  gradnorm: 1.4e-09, fraction:4e-07, efft:0
# iter 1200 | Loss: 0.0242  time: 0.09  gradnorm: 1.4e-09, fraction:4.3e-07, efft:0
# iter 1300 | Loss: 0.0167  time: 0.087  gradnorm: 1.4e-09, fraction:6e-07, efft:0
# iter 1400 | Loss: 0.0122  time: 0.086  gradnorm: 1.4e-09, fraction:1.1e-06, efft:0
# iter 1500 | Loss: 0.0091  time: 0.087  gradnorm: 1.4e-09, fraction:1.2e-06, efft:0
# iter 1600 | Loss: 0.00634  time: 0.086  gradnorm: 1.4e-09, fraction:1.5e-06, efft:0
# iter 1700 | Loss: 0.00536  time: 0.084  gradnorm: 1.4e-09, fraction:2.7e-06, efft:0
# iter 1800 | Loss: 0.00486  time: 0.089  gradnorm: 1.4e-09, fraction:1.9e-06, efft:0
# iter 1900 | Loss: 0.526  time: 0.086  gradnorm: 1.4e-09, fraction:1.5e-09, efft:0
# iter 2000 | Loss: 0.00382  time: 0.087  gradnorm: 1.4e-09, fraction:2.2e-06, efft:0
# (2, 1)
# iter 0 | Loss: 1.0  time: 0.016  gradnorm: 1.2e-10, fraction:1.1e-08, efft:0
# iter 1 | Loss: 0.997  time: 0.01  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 2 | Loss: 0.997  time: 0.01  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 3 | Loss: 0.997  time: 0.011  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 4 | Loss: 0.997  time: 0.011  gradnorm: 1.2e-10, fraction:2.1e-08, efft:0
# iter 100 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:1.4e-08, efft:0
# iter 200 | Loss: 1.0  time: 0.014  gradnorm: 1.2e-10, fraction:7.7e-09, efft:0
# iter 300 | Loss: 0.999  time: 0.014  gradnorm: 1.2e-10, fraction:5.1e-09, efft:0
# iter 400 | Loss: 0.995  time: 0.015  gradnorm: 1.2e-10, fraction:3.7e-09, efft:0
# iter 500 | Loss: 0.981  time: 0.014  gradnorm: 1.2e-10, fraction:2.8e-09, efft:0
# iter 600 | Loss: 0.989  time: 0.013  gradnorm: 1.2e-10, fraction:2.3e-09, efft:0
# iter 700 | Loss: 0.976  time: 0.014  gradnorm: 1.2e-10, fraction:1.8e-09, efft:0
# iter 800 | Loss: 0.959  time: 0.015  gradnorm: 1.2e-10, fraction:1.5e-09, efft:0
# iter 900 | Loss: 0.951  time: 0.015  gradnorm: 1.2e-10, fraction:1.3e-09, efft:0
# iter 1000 | Loss: 0.942  time: 0.015  gradnorm: 1.2e-10, fraction:1.2e-09, efft:0
# iter 1100 | Loss: 0.919  time: 0.014  gradnorm: 1.2e-10, fraction:1e-09, efft:0
# iter 1200 | Loss: 0.918  time: 0.014  gradnorm: 1.2e-10, fraction:9.1e-10, efft:0
# iter 1300 | Loss: 0.881  time: 0.014  gradnorm: 1.2e-10, fraction:8.3e-10, efft:0
# iter 1400 | Loss: 0.876  time: 0.014  gradnorm: 1.2e-10, fraction:7.6e-10, efft:0
# iter 1500 | Loss: 0.84  time: 0.014  gradnorm: 1.2e-10, fraction:7e-10, efft:0
# iter 1600 | Loss: 0.828  time: 0.014  gradnorm: 1.2e-10, fraction:6.6e-10, efft:0
# iter 1700 | Loss: 0.814  time: 0.016  gradnorm: 1.2e-10, fraction:6.3e-10, efft:0
# iter 1800 | Loss: 0.796  time: 0.015  gradnorm: 1.2e-10, fraction:5.9e-10, efft:0
# iter 1900 | Loss: 0.761  time: 0.015  gradnorm: 1.2e-10, fraction:5.8e-10, efft:0
# iter 2000 | Loss: 0.729  time: 0.016  gradnorm: 1.2e-10, fraction:5.8e-10, efft:0
# (2, 3)
# iter 0 | Loss: 1.0  time: 0.038  gradnorm: 2.9e-10, fraction:2.9e-08, efft:0
# iter 1 | Loss: 0.997  time: 0.034  gradnorm: 2.9e-10, fraction:6.7e-08, efft:0
# iter 2 | Loss: 0.997  time: 0.039  gradnorm: 2.9e-10, fraction:6.7e-08, efft:0
# iter 3 | Loss: 0.997  time: 0.035  gradnorm: 2.9e-10, fraction:6.7e-08, efft:0
# iter 4 | Loss: 0.996  time: 0.035  gradnorm: 2.9e-10, fraction:6.6e-08, efft:0
# iter 100 | Loss: 0.997  time: 0.042  gradnorm: 2.9e-10, fraction:1.4e-08, efft:0
# iter 200 | Loss: 0.987  time: 0.038  gradnorm: 2.9e-10, fraction:7.1e-09, efft:0
# iter 300 | Loss: 0.973  time: 0.04  gradnorm: 2.9e-10, fraction:4.5e-09, efft:0
# iter 400 | Loss: 0.951  time: 0.04  gradnorm: 2.9e-10, fraction:3.2e-09, efft:0
# iter 500 | Loss: 0.914  time: 0.038  gradnorm: 2.9e-10, fraction:2.5e-09, efft:0
# iter 600 | Loss: 0.891  time: 0.037  gradnorm: 2.9e-10, fraction:2e-09, efft:0
# iter 700 | Loss: 0.843  time: 0.038  gradnorm: 2.9e-10, fraction:1.7e-09, efft:0
# iter 800 | Loss: 0.787  time: 0.039  gradnorm: 2.9e-10, fraction:1.5e-09, efft:0
# iter 900 | Loss: 0.734  time: 0.04  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1000 | Loss: 0.678  time: 0.038  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1100 | Loss: 0.61  time: 0.039  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1200 | Loss: 0.56  time: 0.038  gradnorm: 2.9e-10, fraction:1.3e-09, efft:0
# iter 1300 | Loss: 0.488  time: 0.041  gradnorm: 2.9e-10, fraction:1.4e-09, efft:0
# iter 1400 | Loss: 0.436  time: 0.039  gradnorm: 2.9e-10, fraction:1.6e-09, efft:0
# iter 1500 | Loss: 0.382  time: 0.038  gradnorm: 2.9e-10, fraction:1.9e-09, efft:0
# iter 1600 | Loss: 0.341  time: 0.038  gradnorm: 2.9e-10, fraction:2.4e-09, efft:0
# iter 1700 | Loss: 0.303  time: 0.039  gradnorm: 2.9e-10, fraction:3.3e-09, efft:0
# iter 1800 | Loss: 0.28  time: 0.041  gradnorm: 2.9e-10, fraction:5.1e-09, efft:0
# iter 1900 | Loss: 0.254  time: 0.037  gradnorm: 2.9e-10, fraction:7.8e-09, efft:0
# iter 2000 | Loss: 0.239  time: 0.04  gradnorm: 2.9e-10, fraction:1e-08, efft:0
# (2, 5)
# iter 0 | Loss: 1.0  time: 0.06  gradnorm: 5.6e-10, fraction:5.2e-08, efft:0
# iter 1 | Loss: 0.997  time: 0.061  gradnorm: 5.6e-10, fraction:1.2e-07, efft:0
# iter 2 | Loss: 0.996  time: 0.061  gradnorm: 5.6e-10, fraction:1.3e-07, efft:0
# iter 3 | Loss: 0.996  time: 0.061  gradnorm: 5.6e-10, fraction:1.3e-07, efft:0
# iter 4 | Loss: 0.996  time: 0.062  gradnorm: 5.6e-10, fraction:1.2e-07, efft:0
# iter 100 | Loss: 0.989  time: 0.061  gradnorm: 5.6e-10, fraction:1.5e-08, efft:0
# iter 200 | Loss: 0.955  time: 0.063  gradnorm: 5.6e-10, fraction:6.8e-09, efft:0
# iter 300 | Loss: 0.901  time: 0.068  gradnorm: 5.6e-10, fraction:4.3e-09, efft:0
# iter 400 | Loss: 0.819  time: 0.065  gradnorm: 5.6e-10, fraction:3.1e-09, efft:0
# iter 500 | Loss: 0.707  time: 0.062  gradnorm: 5.6e-10, fraction:2.6e-09, efft:0
# iter 600 | Loss: 0.606  time: 0.065  gradnorm: 5.6e-10, fraction:2.6e-09, efft:0
# iter 700 | Loss: 0.494  time: 0.065  gradnorm: 5.6e-10, fraction:2.9e-09, efft:0
# iter 800 | Loss: 0.388  time: 0.063  gradnorm: 5.6e-10, fraction:4e-09, efft:0
# iter 900 | Loss: 0.315  time: 0.061  gradnorm: 5.6e-10, fraction:6.3e-09, efft:0
# iter 1000 | Loss: 0.263  time: 0.065  gradnorm: 5.6e-10, fraction:1.3e-08, efft:0
# iter 1100 | Loss: 0.234  time: 0.067  gradnorm: 5.6e-10, fraction:1.9e-08, efft:0
# iter 1200 | Loss: 0.212  time: 0.067  gradnorm: 5.6e-10, fraction:2.9e-08, efft:0
# iter 1300 | Loss: 0.187  time: 0.061  gradnorm: 5.6e-10, fraction:3.4e-08, efft:0
# iter 1400 | Loss: 0.164  time: 0.062  gradnorm: 5.6e-10, fraction:3e-08, efft:0
# iter 1500 | Loss: 0.139  time: 0.061  gradnorm: 5.6e-10, fraction:3.1e-08, efft:0
# iter 1600 | Loss: 0.119  time: 0.063  gradnorm: 5.6e-10, fraction:3.2e-08, efft:0
# iter 1700 | Loss: 0.105  time: 0.068  gradnorm: 5.6e-10, fraction:3.9e-08, efft:0
# iter 1800 | Loss: 0.0902  time: 0.062  gradnorm: 5.6e-10, fraction:3.9e-08, efft:0
# iter 1900 | Loss: 0.0744  time: 0.062  gradnorm: 5.6e-10, fraction:5.7e-08, efft:0
# iter 2000 | Loss: 0.0654  time: 0.064  gradnorm: 5.6e-10, fraction:5.7e-08, efft:0
# (2, 7)
# iter 0 | Loss: 1.0  time: 0.09  gradnorm: 1.4e-09, fraction:1.4e-07, efft:0
# iter 1 | Loss: 0.997  time: 0.083  gradnorm: 1.4e-09, fraction:5.2e-07, efft:0
# iter 2 | Loss: 0.997  time: 0.081  gradnorm: 1.4e-09, fraction:4.4e-07, efft:0
# iter 3 | Loss: 0.997  time: 0.081  gradnorm: 1.4e-09, fraction:3.7e-07, efft:0
# iter 4 | Loss: 0.997  time: 0.081  gradnorm: 1.4e-09, fraction:3.2e-07, efft:0
# iter 100 | Loss: 0.945  time: 0.084  gradnorm: 1.4e-09, fraction:1.3e-08, efft:0
# iter 200 | Loss: 0.752  time: 0.087  gradnorm: 1.4e-09, fraction:6.7e-09, efft:0
# iter 300 | Loss: 0.508  time: 0.086  gradnorm: 1.4e-09, fraction:9e-09, efft:0
# iter 400 | Loss: 0.329  time: 0.088  gradnorm: 1.4e-09, fraction:2.1e-08, efft:0
# iter 500 | Loss: 0.243  time: 0.086  gradnorm: 1.4e-09, fraction:7.8e-08, efft:0
# iter 600 | Loss: 0.2  time: 0.087  gradnorm: 1.4e-09, fraction:7.9e-08, efft:0
# iter 700 | Loss: 0.145  time: 0.091  gradnorm: 1.4e-09, fraction:9.4e-08, efft:0
# iter 800 | Loss: 0.101  time: 0.087  gradnorm: 1.4e-09, fraction:1.9e-07, efft:0
# iter 900 | Loss: 0.0743  time: 0.09  gradnorm: 1.4e-09, fraction:3e-07, efft:0
# iter 1000 | Loss: 0.0548  time: 0.087  gradnorm: 1.4e-09, fraction:2.7e-07, efft:0
# iter 1100 | Loss: 0.0388  time: 0.085  gradnorm: 1.4e-09, fraction:3.3e-07, efft:0
# iter 1200 | Loss: 0.0298  time: 0.087  gradnorm: 1.4e-09, fraction:3.4e-07, efft:0
# iter 1300 | Loss: 0.022  time: 0.085  gradnorm: 1.4e-09, fraction:6.5e-07, efft:0
# iter 1400 | Loss: 0.0165  time: 0.087  gradnorm: 1.4e-09, fraction:7.4e-07, efft:0
# iter 1500 | Loss: 0.0118  time: 0.082  gradnorm: 1.4e-09, fraction:9.2e-07, efft:0
# iter 1600 | Loss: 0.00821  time: 0.082  gradnorm: 1.4e-09, fraction:1.4e-06, efft:0
# iter 1700 | Loss: 0.00597  time: 0.092  gradnorm: 1.4e-09, fraction:1.6e-06, efft:0
# iter 1800 | Loss: 0.00458  time: 0.088  gradnorm: 1.4e-09, fraction:1.8e-06, efft:0
# iter 1900 | Loss: 0.00325  time: 0.091  gradnorm: 1.4e-09, fraction:3.5e-06, efft:0
# iter 2000 | Loss: 0.00288  time: 0.088  gradnorm: 1.4e-09, fraction:2.9e-06, efft:0
